# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
X=np.array(pd.read_csv('train_x.csv'))

# %%
plt.scatter(X[:,0], X[:, 1])

# %%
y=[[1,2],[3,4]]
y=np.array(y)
y
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
mask=(X[:, 0]<=0.1)&( X[:, 1]>=0.7)
print(X[mask, :])
# Out:
# [[0.09625 0.80875]
#  [0.02875 0.76375]
#  [0.00875 0.72375]
#  [0.0025  0.70625]
#  [0.03625 0.90875]
#  [0.03625 0.705  ]
#  [0.03125 0.7325 ]
#  [0.06875 0.885  ]
#  [0.01875 0.92875]
#  [0.05125 0.70375]
#  [0.0375  0.80125]
#  [0.01    0.77375]
#  [0.08125 0.74   ]
#  [0.06625 0.86125]
#  [0.03625 0.73   ]
#  [0.075   0.87625]
#  [0.0075  0.76   ]
#  [0.07625 0.89875]
#  [0.0225  0.965  ]
#  [0.03875 0.885  ]
#  [0.0375  0.74875]
#  [0.08625 0.84375]
#  [0.0725  0.915  ]
#  [0.0575  0.735  ]
#  [0.03    0.9275 ]
#  [0.02625 0.765  ]
#  [0.0225  0.72   ]
#  [0.0625  0.92   ]
#  [0.09    0.9775 ]
#  [0.065   0.75   ]
#  [0.0025  0.95375]
#  [0.045   0.785  ]
#  [0.035   0.79125]
#  [0.02    0.74625]
#  [0.01875 0.70875]
#  [0.085   0.97625]
#  [0.0325  0.90875]
#  [0.0675  0.7    ]
#  [0.03125 0.73625]
#  [0.04375 0.9625 ]
#  [0.0725  0.9725 ]
#  [0.02625 0.75625]
#  [0.0275  0.77625]
#  [0.03    0.75375]
#  [0.01875 0.72125]
#  [0.03625 0.89375]
#  [0.01    0.78   ]
# ...

# %%
masks=[]
masks.append((X[:, 0]<=0.1)&( X[:, 1]>=0.7))
masks.append((X[:, 0]<=0.2)&( X[:, 1]>=0.8))
print(X[masks[0], :])
# Out:
#   Input In [8]
#     print(X[masks[0], :]
#                         ^
# SyntaxError: unexpected EOF while parsing
